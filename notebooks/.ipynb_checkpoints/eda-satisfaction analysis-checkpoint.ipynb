# %% [markdown]
# # **SATISFACTION CLASSIFIER**
#
# ---
#
# *We have a set of airline passenger data to explore and discover what factors predict the best flight experiences.**

# %% [markdown]
# BOOKSTORES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing the dataset

# %%
data = pd.read_csv("../data/Combined_Satisfaction.csv")
data = data.drop(columns=["id"])
data
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 129875    Male  disloyal Customer   34  Business travel  Business
# 129876    Male     Loyal Customer   23  Business travel  Business
# 129877  Female     Loyal Customer   17  Personal Travel       Eco
# 129878    Male     Loyal Customer   14  Business travel  Business
# 129879  Female     Loyal Customer   42  Personal Travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# 2                  1142                      2
# 3                   562                      2
# 4                   214                      3
# ...                 ...                    ...
# 129875              526                      3
# 129876              646                      4
# 129877              828                      2
# 129878             1127                      3
# 129879              264                      2
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 4                                       3                       3
# ...                                   ...                     ...
# 129875                                  3                       3
# 129876                                  4                       4
# 129877                                  5                       1
# 129878                                  3                       3
# 129879                                  5                       2
#
#         Gate location  ...  On-board service  Leg room service  \
# 0                   1  ...                 4                 3
# 1                   3  ...                 1                 5
# 2                   2  ...                 4                 3
# 3                   5  ...                 2                 5
# 4                   3  ...                 3                 4
# ...               ...  ...               ...               ...
# 129875              1  ...                 3                 2
# 129876              4  ...                 4                 5
# 129877              5  ...                 4                 3
# 129878              3  ...                 3                 2
# 129879              5  ...                 1                 2
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      4                4                 5            5
# 1                      3                1                 4            1
# 2                      4                4                 4            5
# 3                      3                1                 4            2
# 4                      4                3                 3            3
# ...                  ...              ...               ...          ...
# 129875                 4                4                 5            4
# 129876                 5                5                 5            4
# 129877                 4                5                 4            2
# 129878                 5                4                 5            4
# 129879                 1                1                 1            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                               25                      18.0
# 1                                1                       6.0
# 2                                0                       0.0
# 3                               11                       9.0
# 4                                0                       0.0
# ...                            ...                       ...
# 129875                           0                       0.0
# 129876                           0                       0.0
# 129877                           0                       0.0
# 129878                           0                       0.0
# 129879                           0                       0.0
#
#                    satisfaction  Unnamed: 0
# 0       neutral or dissatisfied         NaN
# 1       neutral or dissatisfied         NaN
# 2                     satisfied         NaN
# 3       neutral or dissatisfied         NaN
# 4                     satisfied         NaN
# ...                         ...         ...
# 129875  neutral or dissatisfied     25971.0
# 129876                satisfied     25972.0
# 129877  neutral or dissatisfied     25973.0
# 129878                satisfied     25974.0
# 129879  neutral or dissatisfied     25975.0
#
# [129880 rows x 24 columns]

# %%
data.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  129880.000000    129880.000000          129880.000000
# mean       39.427957      1190.316392               2.728696
# std        15.119360       997.452477               1.329340
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       844.000000               3.000000
# 75%        51.000000      1744.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      129880.000000           129880.000000
# mean                            3.057599                2.756876
# std                             1.526741                1.401740
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding   Seat comfort  \
# count  129880.000000   129880.000000    129880.000000  129880.000000
# mean        2.976925        3.204774         3.252633       3.441361
# std         1.278520        1.329933         1.350719       1.319289
# min         0.000000        0.000000         0.000000       0.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         3.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count           129880.000000     129880.000000     129880.000000
# mean                 3.358077          3.383023          3.350878
# std                  1.334049          1.287099          1.316252
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service    Cleanliness  \
# count     129880.000000    129880.000000     129880.000000  129880.000000
# mean           3.632114         3.306267          3.642193       3.286326
# std            1.180025         1.266185          1.176669       1.313682
# min            1.000000         0.000000          0.000000       0.000000
# 25%            3.000000         3.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes    Unnamed: 0
# count               129880.000000             129487.000000  25976.000000
# mean                    14.713713                 15.091129  12987.500000
# std                     38.071126                 38.465650   7498.769632
# min                      0.000000                  0.000000      0.000000
# 25%                      0.000000                  0.000000   6493.750000
# 50%                      0.000000                  0.000000  12987.500000
# 75%                     12.000000                 13.000000  19481.250000
# max                   1592.000000               1584.000000  25975.000000

# %% [markdown]
# # **1. What is the general level of passenger satisfaction? What are the percentages?**

# %%
satisfaction_counts = data['satisfaction'].value_counts(normalize=True) * 100

plt.figure(figsize=(8,6))
satisfaction_counts.plot(kind='bar', color=['skyblue', 'salmon'])
plt.title('General Level of Passenger Satisfaction')
plt.xlabel('Satisfaction Level')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
for index, value in enumerate(satisfaction_counts):
    plt.text(index, value + 1, f'{value:.2f}%', ha='center', va='bottom')
plt.show()

satisfaction_df = satisfaction_counts.rename("Percentage").reset_index().rename(columns={"index": "Satisfaction Level"})

# %% [markdown]
# 1. Results: The bar graph clearly shows that a higher proportion of passengers are in the "Neutral or Dissatisfied" level compared to those who are "Satisfied"
#     1. Neutral or Dissatisfied Majority:
#         - More than half of passengers (56.10%) have a flight experience that they rate as neutral or unsatisfactory
#     2. Satisfied Minority:
#         - 43.90% of passengers report being satisfied with their flight experience
#
# ---
#
# 2. Conclusion: This distribution suggests that the "Fly High" aircraft has a considerable opportunity to improve the experience of its passengers to increase the level of satisfactionfaction.

# %% [markdown]
# # **2. How does satisfaction vary depending on the gender of passengers?**

# %%
plt.figure(figsize=(10, 6))

satisfaction_by_gender = data.groupby('Gender')['satisfaction'].value_counts(normalize=True).unstack() * 100
for gender in satisfaction_by_gender.index:
    plt.plot(satisfaction_by_gender.columns, satisfaction_by_gender.loc[gender], marker='o', label=gender)
    for x, y in zip(satisfaction_by_gender.columns, satisfaction_by_gender.loc[gender]):
        plt.annotate(f'{y:.2f}%', (x, y), textcoords="offset points", xytext=(0,10), ha='center')

plt.title('Satisfaction according to the Gender of Passengers')
plt.xlabel('Satisfaction Level')
plt.ylabel('Percentage')
plt.legend(title='Gender')
plt.grid(True)
plt.show()

# %% [markdown]
# 1. Results
#     1. Female:
#         - Neutral or dissatisfied: 56.46%
#         - Satisfied: 43.54%
#     2. Male:
#         - Neutral or dissatisfied: 55.73%
#         - Satisfied: 44.27%
#
# ---
#
# 2. Conclusions: Both genders show greater dissatisfaction, with a slight trend of greater satisfaction in men.

# %% [markdown]
# # **3. Are there significant differences by age group?**

# %%
bins = [0, 18, 30, 45, 60, 100]
labels = ['0-18', '19-30', '31-45', '46-60', '61+']
data['Age Group'] = pd.cut(data['Age'], bins=bins, labels=labels, right=False)

age_satisfaction_counts = data.groupby('Age Group')['satisfaction'].value_counts(normalize=True).unstack() * 100

group_labels = ['0-18 years', '19-30 years', '31-45 years', '46-60 years', '61+ years']
satisfaction_labels = ['Satisfied', 'Neutral/Dissatisfied']

sizes = [age_satisfaction_counts.loc['0-18', 'satisfied'], age_satisfaction_counts.loc['0-18', 'neutral or dissatisfied'],
         age_satisfaction_counts.loc['19-30', 'satisfied'], age_satisfaction_counts.loc['19-30', 'neutral or dissatisfied'],
         age_satisfaction_counts.loc['31-45', 'satisfied'], age_satisfaction_counts.loc['31-45', 'neutral or dissatisfied'],
         age_satisfaction_counts.loc['46-60', 'satisfied'], age_satisfaction_counts.loc['46-60', 'neutral or dissatisfied'],
         age_satisfaction_counts.loc['61+', 'satisfied'], age_satisfaction_counts.loc['61+', 'neutral or dissatisfied']]

colors = ['#ff9999', '#ff9999', '#66b3ff', '#66b3ff', '#99ff99', '#99ff99', '#ffcc99', '#ffcc99', '#c2c2f0', '#c2c2f0']

plt.figure(figsize=(14, 10))
patches, texts, autotexts = plt.pie(sizes, labels=['']*len(sizes), autopct='%1.1f%%', startangle=140, colors=colors, pctdistance=0.85)

for i, autotext in enumerate(autotexts):
    if i % 2 == 0:
        autotext.set_text(f'Satisfied\n{autotext.get_text()}')
    else:
        autotext.set_text(f'Neutral/Dissatisfied\n{autotext.get_text()}')

for i in range(0, len(group_labels)):
    ang1 = patches[2*i].theta2 - (patches[2*i].theta2 - patches[2*i].theta1) / 2
    ang2 = patches[2*i+1].theta2 - (patches[2*i+1].theta2 - patches[2*i+1].theta1) / 2
    ang = (ang1 + ang2) / 2
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    plt.annotate(group_labels[i],
                 xy=(x, y), xytext=(1.02 * np.sign(x), 1.02 * y),
                 horizontalalignment=horizontalalignment,
                 bbox=dict(facecolor='beige', edgecolor='black', boxstyle='round,pad=0.3'))

plt.title('Percentage of Satisfied and Dissatisfied Passengers by Age Group - IN GENERAL')
plt.axis('equal')
plt.show()
# Out:
# C:\Users\comad\AppData\Local\Temp\ipykernel_8108\1153370845.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_satisfaction_counts = data.groupby('Age Group')['satisfaction'].value_counts(normalize=True).unstack() * 100

# %%
satisfaction_by_age_group = data.groupby('Age Group')['satisfaction'].value_counts(normalize=True).unstack() * 100

plt.figure(figsize=(10, 6))
bars = satisfaction_by_age_group.plot(kind='bar', stacked=True, figsize=(10, 6), color=['#FF6347', '#32CD32'])

for container in bars.containers:
    bars.bar_label(container, fmt='%.2f%%', label_type='center')

plt.title('Satisfaction by Passenger Age Group - IN PARTICULAR')
plt.xlabel('Age group')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend(title='Satisfaction')
plt.show()
# Out:
# C:\Users\comad\AppData\Local\Temp\ipykernel_8108\1221259716.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   satisfaction_by_age_group = data.groupby('Age Group')['satisfaction'].value_counts(normalize=True).unstack() * 100

# %% [markdown]
# 1. Results
#     1. Passengers aged 46-60 show the highest proportion of satisfaction (57.71%), while the youngest passengers (0-18 years) are the most dissatisfied (81.89%)
#
# ---
#
# 2. Conclusion
#     1. .Satisfaction is higher in the 31-45 and 46-60 age group
#     2.   Passengers aged 0-18 and over 61 show significantly higher levels of dissatisfaction

# %% [markdown]
# # **4. What differences exist in satisfaction between loyal and non-loyal customers?**

# %%
customer_types_counts = data['Customer Type']
customer_types_counts
# Out:
# 0            Loyal Customer
# 1         disloyal Customer
# 2            Loyal Customer
# 3            Loyal Customer
# 4            Loyal Customer
#                 ...
# 129875    disloyal Customer
# 129876       Loyal Customer
# 129877       Loyal Customer
# 129878       Loyal Customer
# 129879       Loyal Customer
# Name: Customer Type, Length: 129880, dtype: object

# %%
customer_types_counts = data['Customer Type'].value_counts()
customer_types_counts
# Out:
# Customer Type
# Loyal Customer       106100
# disloyal Customer     23780
# Name: count, dtype: int64

# %%
total_count = customer_types_counts.sum()
percentages = (customer_types_counts / total_count) * 100

# %%
plt.figure(figsize=(8, 6))
bars = customer_types_counts.plot(kind='bar', color=['green', 'red'])
#percentage
for bar, percentage in zip(bars.patches, percentages):
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f'{percentage:.2f}%',
        ha='center',
        va='bottom'
    )

plt.title('Number of Loyal and Disloyal Customers')
plt.xlabel('Customer Type')
plt.ylabel('Cantidad Customer Type ')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# 1. Results:
#    1.  The difference is that there are more loyal customers at 81.53% than disloyal customers at 18.47%.

# %% [markdown]
# # **5. How does the type of trip (Personal vs. Business) affect passenger satisfaction?**

# %%
travel_types = data['Type of Travel']
travel_types
# Out:
# 0         Personal Travel
# 1         Business travel
# 2         Business travel
# 3         Business travel
# 4         Business travel
#                ...
# 129875    Business travel
# 129876    Business travel
# 129877    Personal Travel
# 129878    Business travel
# 129879    Personal Travel
# Name: Type of Travel, Length: 129880, dtype: object

# %%
travel_types_counts = data['Type of Travel'].value_counts()
travel_types_counts
# Out:
# Type of Travel
# Business travel    89693
# Personal Travel    40187
# Name: count, dtype: int64

# %%
counts = data.groupby(['Type of Travel', 'satisfaction']).size().unstack(fill_value=0)

# %%
total_counts = counts.sum(axis=1)
percentages = counts.div(total_counts, axis=0) * 100

# %%
plt.figure(figsize=(12, 6))
ax = counts.plot(kind='bar', color=['orange', 'blue'], width=0.4)

plt.title('Trip Type Satisfaction')
plt.xlabel('Type of travel')
plt.ylabel('Amount')
plt.xticks(rotation=45)
plt.legend(title='Satisfaction')
plt.tight_layout()

for i, (index, row) in enumerate(percentages.iterrows()):
    for j, value in enumerate(row):
        ax.text(i + (j * 0.2) - 0.1, counts.iloc[i, j] + 500, f'{value:.1f}%', ha='center', va='bottom')

plt.show()

# %% [markdown]
# 1. Result:
#     1. The type of trip greatly affects passenger satisfaction. In business travel, there are more satisfied passengers, with 58.8%, compared to personal travel, with only 10.0%. Additionally, in business travel, dissatisfaction or neutrality is lower, with 41.2% of 71,655 passengers, whereas in personal travel, dissatisfaction or neutrality is higher, with 90,0% of 32,249 passengers.
#     2. Conlusion: It can be said that in business travel, there are more satisfied passengers than in personal travel, and there are more dissatisfied or neutral passengers in personal travel than in business travel.

# %% [markdown]
# # **6. What services most influence overall passenger satisfaction (wifi, inflight entertainment, seat comfort, etc.)?**

# %%
columns_of_services = ['Inflight wifi service','Departure/Arrival time convenient','Ease of Online booking','Gate location','Inflight entertainment','On-board service','Leg room service','Baggage handling','Checkin service','Inflight service','Cleanliness']
services = data[columns_of_services]
services
# Out:
#         Inflight wifi service  Departure/Arrival time convenient  \
# 0                           3                                  4
# 1                           3                                  2
# 2                           2                                  2
# 3                           2                                  5
# 4                           3                                  3
# ...                       ...                                ...
# 129875                      3                                  3
# 129876                      4                                  4
# 129877                      2                                  5
# 129878                      3                                  3
# 129879                      2                                  5
#
#         Ease of Online booking  Gate location  Inflight entertainment  \
# 0                            3              1                       5
# 1                            3              3                       1
# 2                            2              2                       5
# 3                            5              5                       2
# 4                            3              3                       3
# ...                        ...            ...                     ...
# 129875                       3              1                       4
# 129876                       4              4                       4
# 129877                       1              5                       2
# 129878                       3              3                       4
# 129879                       2              5                       1
#
#         On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                      4                 3                 4                4
# 1                      1                 5                 3                1
# 2                      4                 3                 4                4
# 3                      2                 5                 3                1
# 4                      3                 4                 4                3
# ...                  ...               ...               ...              ...
# 129875                 3                 2                 4                4
# 129876                 4                 5                 5                5
# 129877                 4                 3                 4                5
# 129878                 3                 2                 5                4
# 129879                 1                 2                 1                1
#
#         Inflight service  Cleanliness
# 0                      5            5
# 1                      4            1
# 2                      4            5
# 3                      4            2
# 4                      3            3
# ...                  ...          ...
# 129875                 5            4
# 129876                 5            4
# 129877                 4            2
# 129878                 5            4
# 129879                 1            1
#
# [129880 rows x 11 columns]

# %%
satisfaction = data['satisfaction']
satisfaction
# Out:
# 0         neutral or dissatisfied
# 1         neutral or dissatisfied
# 2                       satisfied
# 3         neutral or dissatisfied
# 4                       satisfied
#                    ...
# 129875    neutral or dissatisfied
# 129876                  satisfied
# 129877    neutral or dissatisfied
# 129878                  satisfied
# 129879    neutral or dissatisfied
# Name: satisfaction, Length: 129880, dtype: object

# %%
services = data[columns_of_services]
satisfaction = data['satisfaction']

satisfied_passengers = services[satisfaction == 'satisfied']
unsatisfied_passengers = services[satisfaction == 'neutral or dissatisfied']

average_satisfaction_satisfied = satisfied_passengers.mean()
average_satisfaction_unsatisfied = unsatisfied_passengers.mean()

labels = columns_of_services
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 6))
rects1 = ax.bar(x - width/2, average_satisfaction_satisfied, width, label='satisfied', color='green')
rects2 = ax.bar(x + width/2, average_satisfaction_unsatisfied, width, label='neutral or dissatisfied', color='red')

ax.set_title('Comparison of average satisfaction scores by service')
ax.set_xlabel('Service')
ax.set_ylabel('Average satisfaction score')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# 1. Result:
#    1. The services that most influence passenger satisfaction are: Inflight entertainment, Baggage handling, and Inflight service among satisfied passengers with an average satisfaction score of approximately 3.7 out of 5. For dissatisfied passengers, with an average satisfaction score of approximately 3.3 out of 5, the most influential services are Baggage handling and Inflight service.
#    3. Conclusion: The most influential services for passengers who are satisfied are Inflight entertainment, Baggage handling, and Inflight service, while the most influential services for passengers who are dissatisfied are inflight wifi and ease of online booking.

# %% [markdown]
# # **7. What are the services that most satisfy and which leave the Business class the most dissatisfied?**

# %%
Business  = data['Type of Travel']
Business
# Out:
# 0         Personal Travel
# 1         Business travel
# 2         Business travel
# 3         Business travel
# 4         Business travel
#                ...
# 129875    Business travel
# 129876    Business travel
# 129877    Personal Travel
# 129878    Business travel
# 129879    Personal Travel
# Name: Type of Travel, Length: 129880, dtype: object

# %%
satisfied_passengers = data[(data['Type of Travel'] == 'Business travel') & (data['satisfaction'] == 'satisfied')]

unsatisfied_passengers = data[(data['Type of Travel'] == 'Business travel') & (data['satisfaction'] == 'neutral or dissatisfied')]

# %%
business_class_data = data[data['Class'] == 'Business']

columns_of_services = [
    'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking',
    'Gate location', 'Inflight entertainment', 'On-board service', 'Leg room service',
    'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness'
]

# %%
satisfaction = business_class_data['satisfaction']
services = business_class_data[columns_of_services]

satisfied_passengers = services[satisfaction == 'satisfied']
unsatisfied_passengers = services[satisfaction == 'neutral or dissatisfied']

average_satisfaction_satisfied = satisfied_passengers.mean()
average_satisfaction_unsatisfied = unsatisfied_passengers.mean()

labels = columns_of_services
x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots(figsize=(12, 6))
rects1 = ax.bar(x - width/2, average_satisfaction_satisfied, width, label='Satisfied', color='violet')
rects2 = ax.bar(x + width/2, average_satisfaction_unsatisfied, width, label='Neutral or Dissatisfied', color='turquoise')

ax.set_title('Comparison of average satisfaction scores by service (Business Class)')
ax.set_xlabel('Service')
ax.set_ylabel('Average satisfaction score')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusions:
#
# The graph above shows the average satisfaction score for each service among business class passengers, differentiating between satisfied and neutral/dissatisfied passengers.
#
# Most Satisfactory Services:
#
# - Inflight entertainment
# - Baggage handling
# - On-board service
#
# Least Satisfactory Services:
#
# - Inflight wifi service
# - Seat comfort
# - Gate location
#
# The most satisfactory services for business passengers are in-flight entertainment, baggage handling, and on-board service, while the least satisfactory services include in-flight wifi, seat comfort, and gate location

# %% [markdown]
# # **8. How does delayed departure and arrival affect passenger satisfaction? Is there a correlation?**

# %%
data['satisfaction'] = data['satisfaction'].map({'satisfied': 1, 'neutral or dissatisfied': 0})

avg_departure_delay_satisfaction = data.groupby('satisfaction')['Departure Delay in Minutes'].mean()
avg_arrival_delay_satisfaction = data.groupby('satisfaction')['Arrival Delay in Minutes'].mean()

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.barplot(x=avg_departure_delay_satisfaction.index, y=avg_departure_delay_satisfaction.values, palette=['salmon', 'skyblue'])
plt.title('Average Departure Delay by Satisfaction')
plt.xlabel('Satisfaction (1 = Satisfied, 0 = Neutral/Dissatisfied)')
plt.ylabel('Average Departure Delay (minutes)')
plt.xticks([0, 1], ['Neutral/Dissatisfied', 'Satisfied'])

plt.subplot(1, 2, 2)
sns.barplot(x=avg_arrival_delay_satisfaction.index, y=avg_arrival_delay_satisfaction.values, palette=['salmon', 'skyblue'])
plt.title('Average Arrival Delay by Satisfaction')
plt.xlabel('Satisfaction (1 = Satisfied, 0 = Neutral/Dissatisfied)')
plt.ylabel('Average Arrival Delay (minutes)')
plt.xticks([0, 1], ['Neutral/Dissatisfied', 'Satisfied'])

plt.tight_layout()
plt.show()
# Out:
# C:\Users\comad\AppData\Local\Temp\ipykernel_8108\127541996.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_departure_delay_satisfaction.index, y=avg_departure_delay_satisfaction.values, palette=['salmon', 'skyblue'])
# C:\Users\comad\AppData\Local\Temp\ipykernel_8108\127541996.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_arrival_delay_satisfaction.index, y=avg_arrival_delay_satisfaction.values, palette=['salmon', 'skyblue'])

# %%
data
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 129875    Male  disloyal Customer   34  Business travel  Business
# 129876    Male     Loyal Customer   23  Business travel  Business
# 129877  Female     Loyal Customer   17  Personal Travel       Eco
# 129878    Male     Loyal Customer   14  Business travel  Business
# 129879  Female     Loyal Customer   42  Personal Travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# 2                  1142                      2
# 3                   562                      2
# 4                   214                      3
# ...                 ...                    ...
# 129875              526                      3
# 129876              646                      4
# 129877              828                      2
# 129878             1127                      3
# 129879              264                      2
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 4                                       3                       3
# ...                                   ...                     ...
# 129875                                  3                       3
# 129876                                  4                       4
# 129877                                  5                       1
# 129878                                  3                       3
# 129879                                  5                       2
#
#         Gate location  ...  Leg room service  Baggage handling  \
# 0                   1  ...                 3                 4
# 1                   3  ...                 5                 3
# 2                   2  ...                 3                 4
# 3                   5  ...                 5                 3
# 4                   3  ...                 4                 4
# ...               ...  ...               ...               ...
# 129875              1  ...                 2                 4
# 129876              4  ...                 5                 5
# 129877              5  ...                 3                 4
# 129878              3  ...                 2                 5
# 129879              5  ...                 2                 1
#
#         Checkin service  Inflight service  Cleanliness  \
# 0                     4                 5            5
# 1                     1                 4            1
# 2                     4                 4            5
# 3                     1                 4            2
# 4                     3                 3            3
# ...                 ...               ...          ...
# 129875                4                 5            4
# 129876                5                 5            4
# 129877                5                 4            2
# 129878                4                 5            4
# 129879                1                 1            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction  \
# 0                               25                      18.0             0
# 1                                1                       6.0             0
# 2                                0                       0.0             1
# 3                               11                       9.0             0
# 4                                0                       0.0             1
# ...                            ...                       ...           ...
# 129875                           0                       0.0             0
# 129876                           0                       0.0             1
# 129877                           0                       0.0             0
# 129878                           0                       0.0             1
# 129879                           0                       0.0             0
#
#         Unnamed: 0  Age Group
# 0              NaN       0-18
# 1              NaN      19-30
# 2              NaN      19-30
# 3              NaN      19-30
# 4              NaN        61+
# ...            ...        ...
# 129875     25971.0      31-45
# 129876     25972.0      19-30
# 129877     25973.0       0-18
# 129878     25974.0       0-18
# 129879     25975.0      31-45
#
# [129880 rows x 25 columns]

# %%
correlation_departure_delay = data[['Departure Delay in Minutes', 'satisfaction']].corr().iloc[0, 1]
correlation_arrival_delay = data[['Arrival Delay in Minutes', 'satisfaction']].corr().iloc[0, 1]

print(f'Correlation between Departure Delay and Satisfaction: {correlation_departure_delay}')
print(f'Correlation between Arrival Delay and Satisfaction: {correlation_arrival_delay}')
# Out:
# Correlation between Departure Delay and Satisfaction: -0.05073986595225617
# Correlation between Arrival Delay and Satisfaction: -0.058275092682868554

# %% [markdown]
# *Results:*
#
# *Average Delays:*
#
# - Average departure delay for satisfied passengers: avg_departure_delay_satisfaction[1] minutes.
# - Average departure delay for neutral or dissatisfied passengers: avg_departure_delay_satisfaction[0] minutes.
# - Average arrival delay for satisfied passengers: avg_arrival_delay_satisfaction[1] minutes.
# - Average arrival delay for neutral or dissatisfied passengers: avg_arrival_delay_satisfaction[0] minutes.
#
# *Correlation:*
#
# - Correlation between departure delay and passenger satisfaction: correlation_departure_delay.
# - Correlation between arrival delay and passenger satisfaction: correlation_arrival_delay.
#
# *Conclusion:*
#
# - Average departure and arrival delays tend to be higher for neutral or dissatisfied passengers.
# - There is a negative correlation between delays and passenger satisfaction, indicating that delays tend to decrease passenger satisfaction.

# %% [markdown]
# # **9. Are there significant correlations between different levels of satisfaction?**

# %%
print(data.columns)
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction', 'Unnamed: 0', 'Age Group'],
#       dtype='object')

# %%
corr_df = data[[
    'Inflight wifi service',
    'Departure/Arrival time convenient',
    'Ease of Online booking',
    'Gate location',
    'Food and drink',
    'Online boarding',
    'Seat comfort',
    'Inflight entertainment',
    'On-board service',
    'Leg room service',
    'Baggage handling',
    'Checkin service',
    'Inflight service',
    'Cleanliness',
    'satisfaction'
]].corr(method="pearson")

# %%
corr_df.style.background_gradient(cmap = "coolwarm")
# Out:
# <style type="text/css">
# #T_9bd34_row0_col0, #T_9bd34_row1_col1, #T_9bd34_row2_col2, #T_9bd34_row3_col3, #T_9bd34_row4_col4, #T_9bd34_row5_col5, #T_9bd34_row6_col6, #T_9bd34_row7_col7, #T_9bd34_row8_col8, #T_9bd34_row9_col9, #T_9bd34_row10_col10, #T_9bd34_row11_col11, #T_9bd34_row12_col12, #T_9bd34_row13_col13, #T_9bd34_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9bd34_row0_col1, #T_9bd34_row7_col10, #T_9bd34_row9_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_9bd34_row0_col2 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_9bd34_row0_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_9bd34_row0_col4, #T_9bd34_row0_col13 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_9bd34_row0_col5, #T_9bd34_row3_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_9bd34_row0_col6, #T_9bd34_row0_col10, #T_9bd34_row4_col11, #T_9bd34_row5_col1, #T_9bd34_row9_col5, #T_9bd34_row10_col1, #T_9bd34_row12_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_9bd34_row0_col7, #T_9bd34_row2_col14, #T_9bd34_row14_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_9bd34_row0_col8, #T_9bd34_row13_col8 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_9bd34_row0_col9 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_9bd34_row0_col11, #T_9bd34_row6_col0, #T_9bd34_row8_col0, #T_9bd34_row10_col0, #T_9bd34_row10_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_9bd34_row0_col12 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_9bd34_row0_col14 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_9bd34_row1_col0, #T_9bd34_row14_col9 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_9bd34_row1_col2, #T_9bd34_row5_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_9bd34_row1_col3, #T_9bd34_row2_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_9bd34_row1_col4, #T_9bd34_row1_col7, #T_9bd34_row1_col14, #T_9bd34_row3_col4, #T_9bd34_row3_col5, #T_9bd34_row3_col6, #T_9bd34_row3_col8, #T_9bd34_row3_col9, #T_9bd34_row3_col10, #T_9bd34_row3_col11, #T_9bd34_row3_col12, #T_9bd34_row3_col13, #T_9bd34_row11_col0, #T_9bd34_row11_col2, #T_9bd34_row11_col3, #T_9bd34_row14_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9bd34_row1_col5, #T_9bd34_row1_col10, #T_9bd34_row6_col12, #T_9bd34_row12_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_9bd34_row1_col6, #T_9bd34_row13_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_9bd34_row1_col8, #T_9bd34_row4_col0, #T_9bd34_row13_col0, #T_9bd34_row13_col12 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_9bd34_row1_col9, #T_9bd34_row1_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_9bd34_row1_col11, #T_9bd34_row5_col9, #T_9bd34_row8_col6, #T_9bd34_row8_col13, #T_9bd34_row11_col7 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_9bd34_row1_col12, #T_9bd34_row5_col12, #T_9bd34_row6_col10, #T_9bd34_row10_col6, #T_9bd34_row12_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_9bd34_row2_col0 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_9bd34_row2_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_9bd34_row2_col4, #T_9bd34_row2_col12, #T_9bd34_row4_col3, #T_9bd34_row4_col10, #T_9bd34_row4_col12, #T_9bd34_row9_col3, #T_9bd34_row13_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_9bd34_row2_col5, #T_9bd34_row7_col12, #T_9bd34_row14_col7 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_9bd34_row2_col6, #T_9bd34_row12_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_9bd34_row2_col7, #T_9bd34_row4_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_9bd34_row2_col8, #T_9bd34_row12_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_9bd34_row2_col9, #T_9bd34_row8_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_9bd34_row2_col10, #T_9bd34_row4_col9, #T_9bd34_row7_col2, #T_9bd34_row9_col4, #T_9bd34_row10_col3, #T_9bd34_row10_col4, #T_9bd34_row12_col3, #T_9bd34_row12_col4, #T_9bd34_row14_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_9bd34_row2_col11, #T_9bd34_row7_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_9bd34_row2_col13, #T_9bd34_row4_col2, #T_9bd34_row6_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_9bd34_row3_col0, #T_9bd34_row9_col7 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_9bd34_row3_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_9bd34_row3_col7, #T_9bd34_row8_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_9bd34_row3_col14 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9bd34_row4_col5, #T_9bd34_row5_col11, #T_9bd34_row11_col10 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_9bd34_row4_col6, #T_9bd34_row6_col4 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_9bd34_row4_col7, #T_9bd34_row12_col10 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_9bd34_row4_col8, #T_9bd34_row5_col10 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_9bd34_row4_col13, #T_9bd34_row13_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_9bd34_row4_col14, #T_9bd34_row14_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_9bd34_row5_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_9bd34_row5_col3, #T_9bd34_row6_col3, #T_9bd34_row7_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_9bd34_row5_col4, #T_9bd34_row11_col12 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_9bd34_row5_col6, #T_9bd34_row6_col5 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_9bd34_row5_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_9bd34_row5_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_9bd34_row5_col13 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_9bd34_row5_col14 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_9bd34_row6_col1, #T_9bd34_row8_col4, #T_9bd34_row9_col1, #T_9bd34_row13_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_9bd34_row6_col7 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_9bd34_row6_col8, #T_9bd34_row7_col11 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_9bd34_row6_col9 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_9bd34_row6_col11 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_9bd34_row6_col13 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_9bd34_row6_col14 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_9bd34_row7_col0 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_9bd34_row7_col4 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_9bd34_row7_col5, #T_9bd34_row12_col14 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_9bd34_row7_col6 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_9bd34_row7_col8 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_9bd34_row7_col9 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_9bd34_row7_col13, #T_9bd34_row13_col7 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_9bd34_row7_col14 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_9bd34_row8_col2, #T_9bd34_row10_col2 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_9bd34_row8_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_9bd34_row8_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_9bd34_row8_col9 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_9bd34_row8_col10 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_9bd34_row8_col11 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_9bd34_row8_col12 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_9bd34_row8_col14 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_9bd34_row9_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_9bd34_row9_col2, #T_9bd34_row13_col9 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_9bd34_row9_col6, #T_9bd34_row9_col13, #T_9bd34_row10_col13 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9bd34_row9_col10, #T_9bd34_row9_col12 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_9bd34_row9_col11 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_9bd34_row9_col14 {
#   backgroun

# %%
corr_df.corr(numeric_only = True)['satisfaction']
# Out:
# Inflight wifi service               -0.053527
# Departure/Arrival time convenient   -0.633601
# Ease of Online booking              -0.239567
# Gate location                       -0.539501
# Food and drink                       0.173027
# Online boarding                      0.562166
# Seat comfort                         0.354368
# Inflight entertainment               0.382615
# On-board service                     0.249812
# Leg room service                     0.265885
# Baggage handling                     0.112676
# Checkin service                      0.142570
# Inflight service                     0.107908
# Cleanliness                          0.286696
# satisfaction                         1.000000
# Name: satisfaction, dtype: float64

# %% [markdown]
# Conclusions:
#
# The visualization shows the correlations between satisfaction with different services and overall satisfaction with the airline, where warm colors indicate positive correlations and cool colors indicate negative ones. It is observed that the efficiency of online boarding, seat comfort, and cleanliness are factors with strong positive correlations, significantly influencing passenger satisfaction. On the other hand, the convenience of departure and arrival times and gate location show strong negative correlations, negatively affecting the passenger experience. Other factors such as inflight entertainment, legroom service, and food and drink also contribute positively, although to a lesser extent. The ease of online booking and inflight wifi service have low negative correlations, suggesting that improvements in these areas have minimal impact on overall satisfaction. Overall, the comfort and efficiency of services stand out as the main influencers of passenger satisfaction.

# %% [markdown]
# # **10. What customer segments exist based on demographics, type of customer, type of trip and class? Which ones show higher levels of satisfaction?**

# %%
data
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 129875    Male  disloyal Customer   34  Business travel  Business
# 129876    Male     Loyal Customer   23  Business travel  Business
# 129877  Female     Loyal Customer   17  Personal Travel       Eco
# 129878    Male     Loyal Customer   14  Business travel  Business
# 129879  Female     Loyal Customer   42  Personal Travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# 2                  1142                      2
# 3                   562                      2
# 4                   214                      3
# ...                 ...                    ...
# 129875              526                      3
# 129876              646                      4
# 129877              828                      2
# 129878             1127                      3
# 129879              264                      2
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 4                                       3                       3
# ...                                   ...                     ...
# 129875                                  3                       3
# 129876                                  4                       4
# 129877                                  5                       1
# 129878                                  3                       3
# 129879                                  5                       2
#
#         Gate location  ...  Leg room service  Baggage handling  \
# 0                   1  ...                 3                 4
# 1                   3  ...                 5                 3
# 2                   2  ...                 3                 4
# 3                   5  ...                 5                 3
# 4                   3  ...                 4                 4
# ...               ...  ...               ...               ...
# 129875              1  ...                 2                 4
# 129876              4  ...                 5                 5
# 129877              5  ...                 3                 4
# 129878              3  ...                 2                 5
# 129879              5  ...                 2                 1
#
#         Checkin service  Inflight service  Cleanliness  \
# 0                     4                 5            5
# 1                     1                 4            1
# 2                     4                 4            5
# 3                     1                 4            2
# 4                     3                 3            3
# ...                 ...               ...          ...
# 129875                4                 5            4
# 129876                5                 5            4
# 129877                5                 4            2
# 129878                4                 5            4
# 129879                1                 1            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction  \
# 0                               25                      18.0             0
# 1                                1                       6.0             0
# 2                                0                       0.0             1
# 3                               11                       9.0             0
# 4                                0                       0.0             1
# ...                            ...                       ...           ...
# 129875                           0                       0.0             0
# 129876                           0                       0.0             1
# 129877                           0                       0.0             0
# 129878                           0                       0.0             1
# 129879                           0                       0.0             0
#
#         Unnamed: 0  Age Group
# 0              NaN       0-18
# 1              NaN      19-30
# 2              NaN      19-30
# 3              NaN      19-30
# 4              NaN        61+
# ...            ...        ...
# 129875     25971.0      31-45
# 129876     25972.0      19-30
# 129877     25973.0       0-18
# 129878     25974.0       0-18
# 129879     25975.0      31-45
#
# [129880 rows x 25 columns]

# %%
data = pd.read_csv("../data/train.csv")

segments = data.groupby(['Gender', 'Customer Type', 'Type of Travel', 'Class']).agg(
    total=('id', 'count'),
    satisfied=('satisfaction', lambda x: (x == 'satisfied').sum()),
    satisfaction_percentage=('satisfaction', lambda x: (x == 'satisfied').mean() * 100)
).reset_index()

sorted_segments = segments.sort_values(by='satisfaction_percentage', ascending=False)

sorted_segments.head(10)
# Out:
#     Gender      Customer Type   Type of Travel     Class  total  satisfied  \
# 11    Male     Loyal Customer  Business travel  Business  20116      15709
# 0   Female     Loyal Customer  Business travel  Business  20047      15598
# 12    Male     Loyal Customer  Business travel       Eco   4758       2258
# 1   Female     Loyal Customer  Business travel       Eco   4738       2241
# 2   Female     Loyal Customer  Business travel  Eco Plus   1559        727
# 13    Male     Loyal Customer  Business travel  Eco Plus   1620        747
# 17    Male  disloyal Customer  Business travel  Business   3540       1420
# 6   Female  disloyal Customer  Business travel  Business   3805       1489
# 21    Male  disloyal Customer  Personal Travel       Eco     71         13
# 10  Female  disloyal Customer  Personal Travel       Eco     78         13
#
#     satisfaction_percentage
# 11                78.092066
# 0                 77.807153
# 12                47.456915
# 1                 47.298438
# 2                 46.632457
# 13                46.111111
# 17                40.112994
# 6                 39.132720
# 21                18.309859
# 10                16.666667

# %%
data['Segment'] = data['Gender'] + ' - ' + data['Customer Type'] + ' - ' + data['Type of Travel'] + ' - ' + data['Class']

#data['Satisfaction Score'] = data['satisfaction'].apply(lambda x: 1 if x == 'satisfied' else 0)

plt.figure(figsize=(12, 6))
#sns.violinplot(x='Segmento', y='Satisfaction Score', data=data, inner="point", scale='width')

#sns.countplot(x = data['Segmento'], hue = data['Satisfaction Score'] )

sns.histplot(x = data['Segment'])

plt.xticks(rotation=90)
plt.xlabel('Segment')
plt.ylabel('Satisfaction')
plt.title('Distribution of Satisfaction by Segment of Client')
plt.tight_layout()

plt.show()

# %% [markdown]
# **Observations:**
# - Loyal customers appear to be more satisfied than disloyal ones.
# - Personal trips tend to have higher satisfaction levels than business trips.
# - The "Eco Plus" class shows higher satisfaction compared to the "Eco" class.
#
# **Recommendations:**
# - Focus on improving satisfaction for disloyal customers and business trips.
# - Investigate the reasons behind satisfaction differences among service classes.
